# %%
import os
import pandas as pd
import numpy as np

# %%
os.listdir('.\pokemon')
# Out:
# ['Pokemon.csv']

# %%
poke_df = pd.read_csv('./pokemon/Pokemon.csv')
poke_df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
poke_df = poke_df.sort_values('Total', ascending=False)

# %%
poke_df.reset_index(drop=True,inplace=True)

# %%
poke_df
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 0    384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 1    150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 2    150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 3    382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 4    383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# ..   ...                    ...      ...       ...    ...  ...     ...
# 795   10               Caterpie      Bug       NaN    195   45      30
# 796  265                Wurmple      Bug       NaN    195   45      45
# 797  401              Kricketot      Bug       NaN    194   37      25
# 798  298                Azurill   Normal     Fairy    190   50      20
# 799  191                Sunkern    Grass       NaN    180   30      30
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
